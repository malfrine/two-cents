# %%
import os

# %%
os.chdir("..")

# %%
from loan_repayment_manager.main import main

# %%
main()
# Out:
# name: simple example, monthly_allowance $2,100.00
# portfolio:
# 	name: loan1, type: loan, balance: $-20,000.00, interest_rate: 5.00%, term-length: 360
# 	name: loan2, type: loan, balance: $-10,000.00, interest_rate: 20.00%, term-length: 360
# 	name: loan3, type: loan, balance: $-200,000.00, interest_rate: 4.00%, term-length: 360
# 	name: inv1, type: investment, balance: $0.00, interest_rate: 5.00%, term-length: 360
# solution strategy: snowball
# 	 net worth: 624741.4661400241
# 	 interest paid on loans: -115546.2403591542
# 	 interest earned on investments: 220666.70977569825
# solution strategy: avalanche
# 	 net worth: 766921.7209194017
# 	 interest paid on loans: -56488.01075117639
# 	 interest earned on investments: 303664.6623706745
# solution strategy: avalanche_ball
# 	 net worth: 681271.798648439
# 	 interest paid on loans: -91251.82890903334
# 	 interest earned on investments: 252809.23657659703
# solution strategy: lp
# 	 net worth: 870980.4107302062
# ...
